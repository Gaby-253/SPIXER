# %% [markdown]
# # Imports

# %%
import path_integration as pi

# %% [markdown]
# # Full Path Integration trial

# %%
pi_model = pi.PI(display=False)
pi_model.simulatepi(n_steps_forward=400, n_steps_return=500, tortuosity=7.5)
# Out:
# model built

# %% [markdown]
# # Visualize each layer with rasterplots

# %% [markdown]
# ### Initialize the model

# %%
pi_model = pi.PI(display=False)
pi_model.move(azimuth=20, speedl=0.5, speedr=0.5, generator_cur=0.3)
# Out:
# model built

# %% [markdown]
# ### Move the model (need to be called multiple times for the effect on CPU4 cells to be visible)

# %%
pi_model.move(azimuth=270, speedl=0.5, speedr=0.5, generator_cur=0.3)

# %%
pi_model.display_raster()
# Out:
# N spikes motor LEFT:  0
# N spikes motor RIGHT:  0
